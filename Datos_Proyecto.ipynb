# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("LOGIC.csv")
data=pd.DataFrame(df)

print(data)
# Out:
#        inf  sexo  escolaridad  edad  casado_a  experiencia  pob_mul  \
# 0        0     0           12    18         0          121        0
# 1        0     0            8    48         0         2025        1
# 2        0     1            6    49         0         2304        0
# 3        0     1            0    40         0         2025        1
# 4        0     0            6    37         1         1296        0
# ...    ...   ...          ...   ...       ...          ...      ...
# 24646    0     1           17    56         0         1936        0
# 24647    0     0            6    74         1         5329        0
# 24648    0     1           11    68         1         3844        0
# 24649    0     0           17    61         0         2401        0
# 24650    0     1           13    42         0         1156        0
#
#        migrante_2
# 0               1
# 1               0
# 2               1
# 3               2
# 4               1
# ...           ...
# ...

# %%
print(data["edad"].mean())
print(data["escolaridad"].min())
print(data["experiencia"].max())
print(data["edad"].min())
# Out:
# 44.78512027909618
# 0
# 10404
# 16

# %%
print(data["edad"].max())
# Out:
# 97

# %%
print(data["experiencia"].plot())
plt.title("Experiencia")
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Text(0.5, 1.0, 'Experiencia')

# %%
df.describe()
# Out:
#                 inf          sexo   escolaridad          edad      casado_a  \
# count  24651.000000  24651.000000  24651.000000  24651.000000  24651.000000
# mean       0.148919      0.531459      9.050748     44.785120      0.325463
# std        0.356016      0.499019      4.284448     18.455034      0.468557
# min        0.000000      0.000000      0.000000     16.000000      0.000000
# 25%        0.000000      0.000000      6.000000     29.000000      0.000000
# 50%        0.000000      1.000000      9.000000     43.000000      0.000000
# 75%        0.000000      1.000000     11.000000     59.000000      1.000000
# max        1.000000      1.000000     22.000000     97.000000      1.000000
#
#         experiencia       pob_mul    migrante_2
# count  24651.000000  24651.000000  24651.000000
# mean    2067.893838      0.166687      0.505943
# std     1852.916941      0.372704      0.669591
# min      121.000000      0.000000      0.000000
# ...

# %%
df.head()
# Out:
#    inf  sexo  escolaridad  edad  casado_a  experiencia  pob_mul  migrante_2
# 0    0     0           12    18         0          121        0           1
# 1    0     0            8    48         0         2025        1           0
# 2    0     1            6    49         0         2304        0           1
# 3    0     1            0    40         0         2025        1           2
# 4    0     0            6    37         1         1296        0           1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sexo'].plot(kind='hist', bins=20, title='sexo')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['escolaridad'].plot(kind='hist', bins=20, title='escolaridad')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...
